# %%
# !pip install qpython
# Out:
# Collecting qpython
#   Downloading qPython-2.0.0.tar.gz (28 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: qpython
#   Building wheel for qpython (setup.py): started
#   Building wheel for qpython (setup.py): finished with status 'done'
#   Created wheel for qpython: filename=qPython-2.0.0-py3-none-any.whl size=41178 sha256=26332773f6543e3ade4d7d625421483ea73f907989baf54ab5dbc9e847b84eb7
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\86\13\c9\4afe41d4c544acfdafc91c3af7514a6d8d2e8f646968c0488e
# Successfully built qpython
# Installing collected packages: qpython
# Successfully installed qpython-2.0.0
#   DEPRECATION: Building 'qpython' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'qpython'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import qpython.qconnection as qconn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\qpython\qtype.py:190: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   numpy.bool       : QBOOL,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import qpython.qconnection as qconn
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\qpython\qconnection.py:21
#      18 import struct
#      20 from qpython import MetaData, CONVERSION_OPTIONS
# ---> 21 from qpython.qtype import QException
#      22 from qpython.qreader import QReader, QReaderException
#      23 from qpython.qwriter import QWriter, QWriterException
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\qpython\qtype.py:190
#     163 PY_TYPE = {
#     164     QBOOL:          numpy.bool_,
#     165     QBYTE:          numpy.byte,
#    (...)
#     183     QSTRING_LIST:   numpy.object_,
#     184     }
#     187 # mapping of Python types to corresponding q atoms
#     188 Q_TYPE = {
#     189     bool             : QBOOL,
# --> 190     numpy.bool       : QBOOL,
#     191     numpy.bool_      : QBOOL,
#     192     numpy.byte       : QBYTE,
#     193     numpy.int16      : QSHORT,
#     194     int              : QINT,
#     195     numpy.int32      : QINT,
#     196     long             : QLONG,
#     197     numpy.int64      : QLONG,
#     198     numpy.float32    : QFLOAT,
#     199     float            : QDOUBLE,
#     200     numpy.float64    : QDOUBLE,
#     201     str              : QSTRING,
#     202     bytes            : QSTRING,
#     203     numpy.string_    : QSYMBOL,
#     204     uuid.UUID        : QGUID,
#     205     }
#     208 # mapping of numpy datetime64/timedelta64 to q temporal types
#     209 TEMPORAL_PY_TYPE = {
#     210     'datetime64[M]'    : QMONTH,
#     211     'datetime64[D]'    : QDATE,
#    (...)
#     217     'timedelta64[ns]'  : QTIMESPAN
#     218     }
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\__init__.py:338, in __getattr__(attr)
#     333     warnings.warn(
#     334         f"In the future `np.{attr}` will be defined as the "
#     335         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     337 if attr in __former_attrs__:
# --> 338     raise AttributeError(__former_attrs__[attr])
#     340 if attr == 'testing':
#     341     import numpy.testing as testing
#
# AttributeError: module 'numpy' has no attribute 'bool'.
# `np.bool` was a deprecated alias for the builtin `bool`. To avoid this error in existing code, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
q = qconn.QConnection(host='localhost', port=5000)
q.open()
columns = ["Date", "Open" , "High", "Low", "Close",  "Adj_Close", "Volume", "Sym"]
